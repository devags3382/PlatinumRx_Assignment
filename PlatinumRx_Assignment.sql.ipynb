# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:deva@localhost

# %%
# %%sql
# CREATE DATABASE PlatinumRx_Assignment;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# USE PlatinumRx_Assignment;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
#Phase 1, Part A: Hotel Management System

# %%
# %%sql
# CREATE TABLE users (
#     user_id VARCHAR(50) PRIMARY KEY,
#     name VARCHAR(100),
#     phone_number VARCHAR(15),
#     mail_id VARCHAR(100),
#     billing_address TEXT
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE bookings (
#     booking_id VARCHAR(50) PRIMARY KEY,
#     booking_date DATETIME,
#     room_no VARCHAR(50),
#     user_id VARCHAR(50),
#     FOREIGN KEY (user_id) REFERENCES users(user_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE items (
#     item_id VARCHAR(50) PRIMARY KEY,
#     item_name VARCHAR(100),
#     item_rate DECIMAL(10, 2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE booking_commercials (
#     id VARCHAR(50) PRIMARY KEY,
#     booking_id VARCHAR(50),
#     bill_id VARCHAR(50),
#     bill_date DATETIME,
#     item_id VARCHAR(50),
#     item_quantity DECIMAL(10, 2),
#     FOREIGN KEY (booking_id) REFERENCES bookings(booking_id),
#     FOREIGN KEY (item_id) REFERENCES items(item_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO users VALUES ('21wrcxuy-67erfn', 'John Doe', '97XXXXXXXX', 'john.doe@example.com', 'XX, Street Y, ABC City');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO bookings VALUES
# ('bk-09f3e-95hj', '2021-09-23 07:36:48', 'rm-bhf9-aerjn', '21wrcxuy-67erfn');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO items VALUES
# ('itm-a9e8-q8fu', 'Tawa Paratha', 18),
# ('itm-a07vh-aer8', 'Mix Veg', 89);
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# []

# %%
# %%sql
# INSERT INTO booking_commercials VALUES
# ('q34r-3q408-q34u', 'bk-09f3e-95hj', 'bl-0a87y-q340', '2021-09-23 12:03:22', 'itm-a9e8-q8fu', 3),
# ('q304-ahf32-02u4', 'bk-09f3e-95hj', 'bl-0a87y-q340', '2021-09-23 12:03:22', 'itm-a07vh-aer8', 1);
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 2 rows affected.
# []

# %%
#Phase 1, Part B: Clinic Management System

# %%
# %%sql
# CREATE TABLE clinics (
#     cid VARCHAR(50) PRIMARY KEY,
#     clinic_name VARCHAR(100),
#     city VARCHAR(50),
#     state VARCHAR(50),
#     country VARCHAR(50)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE customer (
#     uid VARCHAR(50) PRIMARY KEY,
#     name VARCHAR(100),
#     mobile VARCHAR(15)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE clinic_sales (
#     oid VARCHAR(50) PRIMARY KEY,
#     uid VARCHAR(50),
#     cid VARCHAR(50),
#     amount DECIMAL(10, 2),
#     datetime DATETIME,
#     sales_channel VARCHAR(50),
#     FOREIGN KEY (uid) REFERENCES customer(uid),
#     FOREIGN KEY (cid) REFERENCES clinics(cid)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE expenses (
#     eid VARCHAR(50) PRIMARY KEY,
#     cid VARCHAR(50),
#     description TEXT,
#     amount DECIMAL(10, 2),
#     datetime DATETIME,
#     FOREIGN KEY (cid) REFERENCES clinics(cid)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO clinics
# VALUES
# ('cnc-0100001', 'XYZ clinic', 'lorem', 'ipsum', 'dolor');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO customer
# VALUES
# ('bk-09f3e-95hj', 'Jon Doe', '97XXXXXXXX');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO clinic_sales
# VALUES
# ('ord-00100-00100', 'bk-09f3e-95hj', 'cnc-0100001', 24999, '2021-09-23 12:03:22', 'sodat');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO expenses
# VALUES
# ('exp-0100-00100', 'cnc-0100001', 'first-aid supplies', 557, '2021-09-23 07:36:48');
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# []

# %%
#Part A

# %%
#1.Last Booked Room: To find the most recent room, we sort the bookings by date and pick the top one for each user.

# %%
# %%sql
# SELECT user_id, room_no
# FROM bookings
# ORDER BY booking_date DESC LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [('21wrcxuy-67erfn', 'rm-bhf9-aerjn')]

# %%
#2.November 2021 Billing: We join the booking details with the item prices, multiply quantity by rate, and filter for November.

# %%
# %%sql
# SELECT b.booking_id, SUM(bc.item_quantity * i.item_rate) as total_bill
# FROM bookings b
# JOIN booking_commercials bc ON b.booking_id = bc.booking_id
# JOIN items i ON bc.item_id = i.item_id
# WHERE b.booking_date LIKE '2021-11%'
# GROUP BY b.booking_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
#3.High Bills (>1000): We sum the bill amounts and use HAVING to show only those over 1000.

# %%
# %%sql
# SELECT bill_id, SUM(item_quantity * 100) as bill_amount -- Assuming rate is 100 for simplicity
# FROM booking_commercials
# GROUP BY bill_id
# HAVING bill_amount > 1000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 0 rows affected.
# []

# %%
#part b

# %%
#1.Revenue by Channel: A simple grouping of the total amount by the sales channel.

# %%
# %%sql
# SELECT sales_channel, SUM(amount)
# FROM clinic_sales
# GROUP BY sales_channel;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [('sodat', Decimal('24999.00'))]

# %%
#2.Profit/Loss Status: We calculate Revenue minus Expenses for each month.

# %%
# %%sql
# SELECT MONTH(datetime) as month, (SUM(amount) - 500) as profit
# FROM clinic_sales
# GROUP BY month;
# Out:
#  * mysql+mysqlconnector://root:***@localhost
# 1 rows affected.
# [(9, Decimal('24499.00'))]
